# %% [markdown]
# <a href="https://colab.research.google.com/github/mbahlin/MAT421/blob/main/MAT421HWE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3.2 Continuity and Differentiation

# %% [markdown]
# Derivative of a function: f'(a) = lim(x->a) (f(x) - f(a))/(x-a)
#
# Rolle's Theorem - Let f: [a,b] -> R be a continuous function and assume that its derivative exists on (a,b). If f(a) = f(b), then there is a < c < b such that f'(c) = 0.
#
# Mean Value Theorem - Let f: [a,b] -> R be a continuous function and assume that its derivative exists on (a,b). If f(a) = f(b), then there is a < c < b such that f(b) = f(a) + (b-a)*f'(c)    =>   f'(c) = (f(b) - f(a))/(b-a).
#
# Chain Rule - Let f: D ⊆ R^d , and let g:D2 -> R^p , where D2 ⊆ R^m. Assume that f is continuously differentiable at x0, an interior point of D1, and that g is continuously differentiable at f(x0), an interior point D2, then J(gof)(x0) = Jg(f(x0))Jf(x0) , as a product of matrices.
#
# Central Difference - To estimate the slope of the function at xj using the line that connects (x_jminus1, f(x_jminus1)) and (x_jplus1, f(x_jplus1)) f'(xj) = (f(x_jplus1) - f(x_jminus1)) / ((x_jplus1)-(x_jminus1)).

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-poster')
# %matplotlib inline

h = 0.2
x = np.arange(0, 2*np.pi, h) 
y = np.sin(x) 

# forward differences
f_diff = np.diff(y)/h 
x_diff = x[:-1:] 
e_sol = np.cos(x_diff) 

# Plot solution
plt.figure(figsize = (12, 8))
plt.plot(x_diff, f_diff, '--', label = 'Finite Difference Approximation')
plt.plot(x_diff, e_sol,label = 'Exact Solution')
plt.legend()
plt.show()

# %% [markdown]
# Taylor Series
# - A representation of a function by an infinite series of polynomials around a point. Defined as: f(x) = sum(inf, n=0) (f^n (a)(x-a)^n)/(n!)
# - Let f:D -> R, where D ⊆ R. Suppose f has m times continuous derivative on [a,b]. Then : f(b) = f(a) + (b-a)f'(a) + (1/2)(b-a)^2 f''(a) + ... + (1/(m-1)!)(b-a)^(m-1) f^(m-1) *(a) + Rm . Where Rm = (1/m!)f^m (a+θ(b-a)) for 0 < θ < 1.

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-poster')

x = np.linspace(-np.pi, np.pi, 200)
y = np.zeros(len(x))

labels = ['First Order', 'Third Order']

plt.figure(figsize = (10,8))
for n, label in zip(range(2), labels):
    y = y + ((-1)**n * (x)**(2*n+1)) / np.math.factorial(2*n+1)
    plt.plot(x,y, label = label)

plt.plot(x, np.sin(x), 'k', label = 'Analytic')
plt.grid()
plt.title('Taylor Series Approximations of Various Orders')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# Multivariate Mean Value - Let f: D -> R, where D ⊆ R^d . Let x0 ∈ D and δ > 0 be such that Bδ(x0) ⊆ D. If f is continuously differentiable on Bδ(x0), then for any x ∈ Bδ(x0), f(x) = f(x0) + ∇(x0 + ξp)^T *p, for some ξ ∈ (0,1) where p = x - x0.
#
# Multivariate Taylor - Let f: D -> R, where D ⊆ R^d . Let x0 ∈ D and δ > 0 be such that Bδ(x0) ⊆ D. If f is three times continuously differentiable on Bδ(x0), then for any x ∈ Bδ(x0), f(x) = f(x0)+ ∇f(x0)^T *p + 1/2 *p^T * H_f (x0)*p + )(|p||^3), where p = x - x0.

# %% [markdown]
# # 3.3 Unconstrained Optimization

# %% [markdown]
# Global Minimizer - Let f: R^d -> R. The point x* ∈ R^d is a global minimizer of f over R^d if f(x) ≥ f(x*) , ∀x ∈ R^d
#
# Local Minimizer - Let f: R^d -> R. The point x* ∈ R^d is a local minimizer of f over R^d if there is δ > 0 such that f(x) ≥ f(x*) , ∀x ∈ Bδ(x*) \ {x*}
#
# Descent Direction and Directional Derivatives - Let f: R^d -> R be continuously differentiable at x0. A vector v is a descent direction for f at x0 if (მf(x)/(მv)) = ∇f(x0)^T v < 0 , if the directional derivative of f at x0 in the direction v is negative.
#
# First-Order Necessary Condition - Let f: R^d -> R be continuously differentiable on R^d. If x0 is a local minimizer, then  ∇f(x0) = 0.
#
# Second-Order Necessary Condition - Let f: R^d -> R be twice continuously differentiable on R^d. If x0 is a local minimizer, then H_f(x0) is PSD
#
# Second-Order Sufficient Condition - Let f: R^d -> R be twice continuously differentiable on R^d. If ∇f(x0) = 0, and H_f(x0) is positive definite, then x0 is a strict local minimizer.

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-poster')

x = np.linspace(0,8)
y = x**2

x1 = np.linspace(0,6)
y1 = x*4.5

plt.plot(x, y,'b',x1,y1,'r')
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# Convex Set - A set D ⊆ R^d is convex if for all x,y ∈ D and all α ∈ [0,1]. (1 - α)x + αy ∈ D.
#
# Convex Function - A function f:R^d -> R is convex for all x,y ∈ D and all α ∈ [0,1]: f((1 - α)x + αy) ≤ (1 - α)f(x) + αf(y).
#
# Affine Functions are Convex - Let w ∈ R^d adn b ∈ R. The function f(x) = w^T x+b is convex.
#
# First-Order Convexity Condition - Let f: R^d -> R be continuously differentiable. Then f is convex if and only if for all x,y ∈ R^d, f(y) ≥ f(x) + ∇f(x)^T (y-x).
# Second-Order Convexity Condition - Let f: R^d -> R be twice continuously differentiable. Then f is convex if and only if for all x ∈ R^d, H_f(x) is PSD.
#
# Global Minimizers of Convex Functions - Let f:R^d -> R be a convex function. Then any local minimizer of f is also a global minimizer.
#
# Steepest Descent - Let f: R^d -> R be continuously differentiable at x0. For any unit vector v ∈ R^d, (მf(x0)/(მv)) ≥ (მf(x0)/(მv*))

# %% [markdown]
# # 3.4 Logistic Regression

# %% [markdown]
# # 3.5 K-Means

# %% [markdown]
# # 3.6 Support Vector Machine
